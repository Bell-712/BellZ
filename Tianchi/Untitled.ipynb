# %%
import pandas as pd
import sys
import sklearn

# %%
import os
datapath = os.path.join("fresh_comp_offline", "", "")

# %%
# Code example
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# Load the data
train_item = pd.read_csv(datapath + "tianchi_fresh_comp_train_item.csv", na_values="n/a")
train_user = pd.read_csv(datapath + "tianchi_fresh_comp_train_user.csv", encoding="utf-8",na_values="n/a")

# %%
train_item.head(10)
# Out:
#      item_id item_geohash  item_category
# 0  100002303          NaN           3368
# 1  100003592          NaN           7995
# 2  100006838          NaN          12630
# 3  100008089          NaN           7791
# 4  100012750          NaN           9614
# 5  100014072          NaN           1032
# 6  100014463          NaN           9023
# 7  100019387          NaN           3064
# 8  100023812          NaN           6700
# 9   10003007          NaN           5827

# %%
item_category=train_item.groupby(['item_category'])

# %%
item_category.groups
item_category['item_id'].count()
# Out:
# {2: Int64Index([20080, 61874, 61875, 61876, 269338, 269339, 269340, 396975, 407011,
#              475549],
#             dtype='int64'),
#  10: Int64Index([ 12974,  17832,  20822,  30583,  34544,  38010,  43516,  46265,
#               54486,  55940,
#              ...
#              577161, 578475, 593300, 596539, 605672, 606250, 608309, 615694,
#              617394, 618669],
#             dtype='int64', length=104),
#  24: Int64Index([    69,    541,   2664,   8262,   8677,  10894,  11994,  16380,
#               20683,  20951,
#              ...
#              594253, 595952, 596583, 605079, 605485, 607969, 610812, 616068,
#              616337, 620792],
#             dtype='int64', length=319),
#  29: Int64Index([ 53383,  53384,  53385,  53386,  53387,  53388,  53389,  53390,
#               53391,  53392,
#              ...
#              467147, 467148, 467149, 484344, 484345, 545709, 545710, 545711,
#              545712, 601607],
#             dtype='int64', length=146),
# ...

# %%
for name,group in train_item.groupby('item_category'):
    print(name)
    print(group)
    print('*******分隔符*********')
# Out:
# 2
#           item_id item_geohash  item_category
# 20080   138454306          NaN              2
# 61874   217066266      95q5ieh              2
# 61875   217066266      96kakqi              2
# 61876   217066266      970unpc              2
# 269338  217066266      9504d13              2
# 269339  217066266      99ac2ph              2
# 269340  217066266      9rfqvfc              2
# 396975   70556387          NaN              2
# 407011   87532868          NaN              2
# 475549  217066266      95539m1              2
# *******分隔符*********
# 10
#           item_id item_geohash  item_category
# 12974   124711687          NaN             10
# 17832   133332842          NaN             10
# 20822   140151951          NaN             10
# 30583   155835005          NaN             10
# 34544   162497895          NaN             10
# 38010   168821763          NaN             10
# 43516   179271764          NaN             10
# 46265    18414575          NaN             10
# ...

# %%
train_user.head(30)
# Out:
#      user_id    item_id  behavior_type user_geohash  item_category  \
# 0   10001082  285259775              1      97lk14c           4076
# 1   10001082    4368907              1          NaN           5503
# 2   10001082    4368907              1          NaN           5503
# 3   10001082   53616768              1          NaN           9762
# 4   10001082  151466952              1          NaN           5232
# 5   10001082   53616768              4          NaN           9762
# 6   10001082  290088061              1          NaN           5503
# 7   10001082  298397524              1          NaN          10894
# 8   10001082   32104252              1          NaN           6513
# 9   10001082  323339743              1          NaN          10894
# 10  10001082  396795886              1          NaN           2825
# 11  10001082    9947871              1          NaN           2825
# 12  10001082  150720867              1      95qoghe           3200
# ...

# %%
#浏览、收藏、加购物车、购买，对应取值分别是1、2、3、4。
train_user_1=train_user.loc[train_user['behavior_type']==1]
train_user_2=train_user.loc[train_user['behavior_type']==2]
train_user_3=train_user.loc[train_user['behavior_type']==3]
train_user_4=train_user.loc[train_user['behavior_type']==4]
